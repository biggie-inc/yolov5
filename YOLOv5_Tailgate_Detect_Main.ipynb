# %% [markdown]
# Setup, Train, Test YOLOv5 models

# %% [markdown]
# # Setup

# %%
# !git clone -b dev https://github.com/biggie-inc/yolov5.git  # clone repo at dev branch
# %cd yolov5
# !pip install -qr requirements.txt  # install dependencies (ignore errors)
# !pip install -qr requirements_2.txt # may need to specify specific TF version
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 2648 (delta 1), reused 4 (delta 1), pack-reused 2642
# Receiving objects: 100% (2648/2648), 24.88 MiB | 30.62 MiB/s, done.
# Resolving deltas: 100% (1734/1734), done.
# /content/yolov5
#      |████████████████████████████████| 276kB 9.5MB/s
#   Building wheel for PyYAML (setup.py) ... done

# %%
import cv2
import matplotlib.pyplot as plt
from collections import Counter as counter
import numpy as np

# %%
import torch
from IPython.display import Image, clear_output  # to display images
from utils.google_utils import gdrive_download  # to download models/datasets

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.7.0+cu101 CPU

# %% [markdown]
# # Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive

# %%
# copy the .zip file into the root directory of cloud VM
#!cp /mydrive/yolov5/yolov5_tailgate_train.zip /content/    # first train/test
# !cp /mydrive/yolov5/tailgate_handle_bounds.zip /content/  # second train/test
# !cp /mydrive/Biggie/train_test_rear_truck_photos.zip /content/ # third train/test
# !cp /mydrive/Biggie/yolov5/train_test_rear_truck_photos2.zip /content/ # retraining with new bbox bounds

# %%
# %%capture
# %cd /content/
# !unzip /content/train_test_rear_truck_photos2.zip
# %cd ./yolov5

# %% [markdown]
# # Train

# %%
# We're going to convert the class index on the .txt files. As we're working with only one class, it's supposed to be class 0.
# If the index is different from 0 then we're going to change it.
# ONLY FOR SINGLE OBJECT DETECTION
# import glob
# import re

# txt_file_paths = glob.glob(r"../train/labels/*.txt")
# for i, file_path in enumerate(txt_file_paths):
#     # get image size
#     with open(file_path, "r") as f_o:
#         lines = f_o.readlines()

#         text_converted = []
#         for line in lines:
#             print(line)
#             numbers = re.findall("[0-9.]+", line)
#             print(numbers)
#             if numbers:

#                 # Define coordinates
#                 text = "{} {} {} {} {}".format(0, numbers[1], numbers[2], numbers[3], numbers[4])
#                 text_converted.append(text)
#                 print(i, file_path)
#                 print(text)
#         # Write file
#         with open(file_path, 'w') as fp:
#             for item in text_converted:
#                 fp.writelines("%s\n" % item)
                
#### FUTURE UPDATE: WRITE CODE THAT BYPASSES CLASSES.TXT #####

# %% [markdown]
# Start training from pretrained `--weights yolov5s.pt`, or from randomly initialized `--weights ''`. Pretrained weights are auto-downloaded from [Google Drive](https://drive.google.com/open?id=1Drs_Aiu7xx6S-ix95f9kNsA6ueKRpN2J).
#
# **All training results are saved to `runs/exp0`** for the first experiment, then `runs/exp1`, `runs/exp2` etc. for subsequent experiments.

# %%
# Start tensorboard (optional)
# %reload_ext tensorboard
# %tensorboard --logdir runs

# %%
# %cd ../yolov5
# Out:
# /content/yolov5

# %%
# Train YOLOv5s on tailgate data
# !python train.py --batch 64 --epochs 500 --data tg_handle_plate_photo_train.yaml --cfg yolov5s_tg_handle_plate.yaml --weights /mydrive/Biggie/yolov5/exp0_tailgate_handle/weights/last_tailgate_handle.pt --name rear_truck_photos_enlarged_bbox --nosave --cache --adam --logdir /mydrive/yolov5
# Out:
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Namespace(adam=True, batch_size=64, bucket='', cache_images=True, cfg='./models/yolov5s_tg_handle_plate.yaml', data='./data/tg_handle_plate_photo_train.yaml', device='', epochs=500, evolve=False, global_rank=-1, hyp='data/hyp.finetune.yaml', img_size=[640, 640], local_rank=-1, logdir='/mydrive/yolov5', multi_scale=False, name='rear_truck_photos_enlarged_bbox', noautoanchor=False, nosave=True, notest=False, rect=False, resume=False, single_cls=False, sync_bn=False, total_batch_size=64, weights='/mydrive/Biggie/yolov5/exp0_tailgate_handle/weights/last_tailgate_handle.pt', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir /mydrive/yolov5", view at http://localhost:6006/
# 2020-12-21 22:10:58.561077: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Hyperparameters {'lr0': 0.01, 'momentum': 0.94, 'weight_decay': 0.0005, 'giou': 0.05, 'cls': 0.4, 'cls_pw': 1.0, 'obj': 0.5, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 1.0, 'translate': 0.1, 'scale': 0.6, 'shear': 1.0, 'perspective': 0.0, 'flipud': 0.01, 'fliplr': 0.5, 'mixup': 0.2}
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     19904  models.common.BottleneckCSP             [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1    161152  models.common.BottleneckCSP             [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  1    641792  models.common.BottleneckCSP             [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    378624  models.common.BottleneckCSP             [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     95104  models.common.BottleneckCSP             [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    313088  models.common.BottleneckCSP             [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  24      [17, 20, 23]  1     21576  models.yolo.Detect                      [3, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model Summary: 191 layers, 7.26049e+06 parameters, 7.26049e+06 gradients
#
# Transferred 362/370 items from /mydrive/Biggie/yolov5/exp0_tailgate_handle/weights/last_tailgate_handle.pt
# Optimizer groups: 62 .bias, 70 conv.weight, 59 other
# Scanning images: 100% 200/200 [00:00<00:00, 6759.99it/s]
# Scanning labels ../3000e_training_set2.cache (199 found, 0 missing, 1 empty, 0 duplicate, for 200 images): 200it [00:00, 10577.92it/s]
# Caching images (0.2GB): 100% 200/200 [00:07<00:00, 25.17it/s]
# Scanning labels ../3000e_training_set2.cache (199 found, 0 missing, 1 empty, 0 duplicate, for 200 images): 200it [00:00, 10476.07it/s]
# Caching images (0.2GB): 100% 200/200 [00:12<00:00, 15.85it/s]
#
# Analyzing anchors... anchors/target = 4.43, Best Possible Recall (BPR) = 1.0000
# Image sizes 640 train, 640 test
# Using 2 dataloader workers
# Starting training for 500 epochs...
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      0/499     6.93G    0.1005   0.02626   0.02851    0.1553        56       640: 100% 4/4 [00:14<00:00,  3.66s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:12<00:00,  3.16s/it]
#                  all         200         595           0           0        0.05     0.00875
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      1/499     12.5G   0.08764    0.0276   0.02401    0.1393        57       640: 100% 4/4 [00:04<00:00,  1.13s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.47s/it]
#                  all         200         595       0.667     0.00337       0.204      0.0527
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      2/499     12.5G   0.08161   0.03107   0.02087    0.1336        70       640: 100% 4/4 [00:04<00:00,  1.15s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.47s/it]
#                  all         200         595       0.667     0.00337       0.359      0.0957
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      3/499     12.5G   0.07402   0.03284   0.01963    0.1265        63       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.48s/it]
#                  all         200         595       0.667     0.00337       0.461       0.134
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      4/499     12.5G   0.06906   0.03604   0.01899    0.1241        76       640: 100% 4/4 [00:04<00:00,  1.14s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.49s/it]
#                  all         200         595       0.667     0.00337       0.478       0.155
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      5/499     12.5G   0.06431   0.03185   0.01794    0.1141        46       640: 100% 4/4 [00:04<00:00,  1.13s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.47s/it]
#                  all         200         595       0.333     0.00168       0.395       0.154
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      6/499     12.5G    0.0619    0.0286   0.01791    0.1084        37       640: 100% 4/4 [00:04<00:00,  1.14s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.49s/it]
#                  all         200         595       0.333     0.00168       0.375       0.148
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      7/499     12.5G   0.06061   0.02934   0.01638    0.1063        51       640: 100% 4/4 [00:04<00:00,  1.13s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.49s/it]
#                  all         200         595       0.333     0.00168       0.374       0.141
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      8/499     12.5G   0.05814   0.03061   0.01582    0.1046        49       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:06<00:00,  1.51s/it]
#                  all         200         595       0.667     0.00337       0.399       0.113
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      9/499     12.5G   0.05502   0.02722   0.01455    0.0968        59       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.50s/it]
#                  all         200         595       0.667     0.00337       0.611        0.25
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     10/499     12.5G   0.05328   0.02557   0.01338   0.09222        53       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.49s/it]
#                  all         200         595       0.667      0.0323       0.559       0.259
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     11/499     12.5G   0.04939   0.02313   0.01234   0.08486        52       640: 100% 4/4 [00:04<00:00,  1.13s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:06<00:00,  1.53s/it]
#                  all         200         595       0.667       0.334       0.625       0.258
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     12/499     12.5G   0.05072   0.02026    0.0132   0.08419        34       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:06<00:00,  1.52s/it]
#                  all         200         595       0.889       0.335       0.623       0.246
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     13/499     12.5G   0.04747   0.01813   0.01148   0.07708        33       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:06<00:00,  1.51s/it]
#                  all         200         595       0.463       0.511       0.571       0.195
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     14/499     12.5G   0.04875   0.01531  0.009323   0.07338        32       640: 100% 4/4 [00:04<00:00,  1.13s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.50s/it]
#                  all         200         595       0.593       0.796        0.79       0.219
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     15/499     12.5G   0.04962   0.01463  0.008531   0.07278        46       640: 100% 4/4 [00:04<00:00,  1.16s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.49s/it]
#                  all         200         595       0.427       0.645       0.626        0.24
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     16/499     12.5G   0.04712   0.01364  0.007588   0.06834        54       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:06<00:00,  1.51s/it]
#                  all         200         595        0.34       0.883       0.817       0.351
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     17/499     12.5G   0.04751    0.0127  0.008067   0.06828        49       640: 100% 4/4 [00:04<00:00,  1.18s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.50s/it]
#                  all         200         595       0.291       0.946       0.891       0.394
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     18/499     12.5G   0.04752   0.01172  0.006797   0.06604        39       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:04<00:00,  1.02s/it]
#                  all         200         595       0.386       0.956       0.863       0.402
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     19/499     12.5G   0.04592   0.01351  0.006054   0.06549        60       640: 100% 4/4 [00:04<00:00,  1.13s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:04<00:00,  1.07s/it]
#                  all         200         595       0.324       0.989       0.828       0.368
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     20/499     12.5G    0.0446   0.01106  0.005603   0.06126        37       640: 100% 4/4 [00:04<00:00,  1.16s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:04<00:00,  1.19s/it]
#                  all         200         595        0.35       0.994       0.908       0.482
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     21/499     12.5G    0.0431   0.01055  0.005009   0.05866        51       640: 100% 4/4 [00:04<00:00,  1.18s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.47s/it]
#                  all         200         595       0.328       0.997       0.918       0.323
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     22/499     12.5G   0.04271   0.01168  0.004719   0.05911        59       640: 100% 4/4 [00:04<00:00,  1.14s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:04<00:00,  1.17s/it]
#                  all         200         595       0.305       0.993       0.943       0.494
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     23/499     12.5G   0.04141   0.01195  0.004734   0.05809        66       640: 100% 4/4 [00:04<00:00,  1.16s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:04<00:00,  1.00s/it]
#                  all         200         595       0.292       0.993       0.863       0.402
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     24/499     12.5G    0.0465    0.0107  0.004396   0.06159        45       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:03<00:00,  1.13it/s]
#                  all         200         595       0.313       0.995       0.792       0.279
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     25/499     12.5G   0.04503   0.01037  0.003888   0.05929        38       640: 100% 4/4 [00:04<00:00,  1.16s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.34it/s]
#                  all         200         595       0.318        0.96       0.724       0.311
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     26/499     12.5G   0.04249   0.01019  0.004112   0.05679        47       640: 100% 4/4 [00:04<00:00,  1.19s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.48it/s]
#                  all         200         595       0.377       0.665       0.539        0.24
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     27/499     12.5G   0.04335  0.009814  0.003832     0.057        34       640: 100% 4/4 [00:04<00:00,  1.18s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.44it/s]
#                  all         200         595       0.448        0.95       0.853       0.434
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     28/499     12.5G   0.04334  0.008807   0.00424   0.05638        41       640: 100% 4/4 [00:04<00:00,  1.14s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:03<00:00,  1.26it/s]
#                  all         200         595       0.399       0.992       0.867       0.435
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     29/499     12.5G   0.04403  0.009727  0.003736   0.05749        46       640: 100% 4/4 [00:04<00:00,  1.16s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:03<00:00,  1.20it/s]
#                  all         200         595       0.335       0.993        0.92       0.452
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     30/499     12.5G   0.04148   0.01006  0.004038   0.05559        24       640: 100% 4/4 [00:04<00:00,  1.21s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:03<00:00,  1.04it/s]
#                  all         200         595       0.293       0.993        0.93       0.433
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     31/499     12.5G   0.03936   0.01029  0.003433   0.05309        50       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.49s/it]
#                  all         200         595       0.183       0.993       0.955       0.371
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     32/499     12.5G   0.04021   0.01054  0.003944   0.05469        59       640: 100% 4/4 [00:04<00:00,  1.20s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:06<00:00,  1.54s/it]
#                  all         200         595       0.179       0.993       0.881       0.449
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     33/499     12.5G   0.03775  0.009487  0.003834   0.05107        48       640: 100% 4/4 [00:04<00:00,  1.14s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.43s/it]
#                  all         200         595       0.437       0.997        0.94       0.459
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     34/499     12.5G   0.03735  0.009506  0.003779   0.05063        50       640: 100% 4/4 [00:04<00:00,  1.13s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:03<00:00,  1.30it/s]
#                  all         200         595       0.489       0.995       0.942       0.534
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     35/499     12.5G     0.037  0.009742  0.003569   0.05031        46       640: 100% 4/4 [00:04<00:00,  1.19s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.36it/s]
#                  all         200         595       0.481       0.993       0.937       0.511
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     36/499     12.5G   0.03857  0.008766  0.003334   0.05067        35       640: 100% 4/4 [00:04<00:00,  1.15s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.48s/it]
#                  all         200         595       0.403       0.993       0.939       0.533
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     37/499     12.5G   0.03874  0.009952   0.00327   0.05196        43       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.49s/it]
#                  all         200         595       0.397       0.995       0.978       0.642
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     38/499     12.5G   0.03813  0.009892  0.003773   0.05179        58       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:06<00:00,  1.58s/it]
#                  all         200         595       0.114       0.997       0.952       0.557
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     39/499     12.5G   0.03599    0.0095  0.003167   0.04866        38       640: 100% 4/4 [00:04<00:00,  1.16s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.49s/it]
#                  all         200         595       0.192       0.993       0.973       0.631
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     40/499     12.5G    0.0353   0.01088  0.003316    0.0495        69       640: 100% 4/4 [00:04<00:00,  1.13s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.48s/it]
#                  all         200         595       0.225       0.997       0.987       0.684
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     41/499     12.5G   0.03565  0.008783  0.003217   0.04765        44       640: 100% 4/4 [00:04<00:00,  1.14s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.49s/it]
#                  all         200         595       0.171       0.993       0.983       0.515
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     42/499     12.5G   0.03896   0.01089  0.003344    0.0532        73       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:06<00:00,  1.53s/it]
#                  all         200         595       0.128       0.997       0.945       0.611
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     43/499     12.5G   0.03673   0.01029  0.003404   0.05042        81       640: 100% 4/4 [00:04<00:00,  1.15s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.50s/it]
#                  all         200         595       0.124       0.998        0.99       0.648
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     44/499     12.5G   0.03617  0.009412   0.00313   0.04871        55       640: 100% 4/4 [00:04<00:00,  1.14s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:06<00:00,  1.50s/it]
#                  all         200         595       0.218       0.998       0.871       0.513
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     45/499     12.5G   0.03722   0.01022  0.003246   0.05068        52       640: 100% 4/4 [00:04<00:00,  1.16s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:06<00:00,  1.52s/it]
#                  all         200         595       0.232       0.998       0.991       0.643
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     46/499     12.5G   0.03488  0.007991  0.002617   0.04549        38       640: 100% 4/4 [00:04<00:00,  1.15s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:06<00:00,  1.52s/it]
#                  all         200         595       0.148       0.995       0.985        0.62
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     47/499     12.5G   0.03532   0.01088  0.002697    0.0489        69       640: 100% 4/4 [00:04<00:00,  1.16s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:06<00:00,  1.53s/it]
#                  all         200         595       0.133       0.995       0.989       0.645
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     48/499     12.5G   0.03487   0.00941  0.002908   0.04719        50       640: 100% 4/4 [00:04<00:00,  1.18s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.47s/it]
#                  all         200         595       0.272       0.995       0.989       0.598
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     49/499     12.5G    0.0344  0.009766  0.002804   0.04697        61       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:06<00:00,  1.53s/it]
#                  all         200         595       0.306       0.995       0.982       0.521
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     50/499     12.5G   0.03461  0.009488  0.002885   0.04698        62       640: 100% 4/4 [00:04<00:00,  1.18s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.44s/it]
#                  all         200         595       0.278       0.993       0.989       0.588
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     51/499     12.5G   0.03478   0.01093  0.003094    0.0488        81       640: 100% 4/4 [00:04<00:00,  1.15s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.48s/it]
#                  all         200         595       0.308       0.993       0.966        0.62
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     52/499     12.5G   0.03551  0.008322  0.002642   0.04647        36       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.32s/it]
#                  all         200         595       0.269       0.997       0.988       0.681
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     53/499     12.5G    0.0352  0.009829  0.002917   0.04795        59       640: 100% 4/4 [00:04<00:00,  1.16s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:06<00:00,  1.52s/it]
#                  all         200         595       0.127       0.993       0.958       0.584
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     54/499     12.5G   0.03577  0.008638  0.002886   0.04729        38       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:06<00:00,  1.54s/it]
#                  all         200         595        0.14           1       0.993       0.628
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     55/499     12.5G   0.03365  0.009457  0.002737   0.04584        53       640: 100% 4/4 [00:04<00:00,  1.20s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:06<00:00,  1.52s/it]
#                  all         200         595       0.135       0.997       0.992       0.749
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     56/499     12.5G    0.0333  0.008905  0.002595    0.0448        42       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.50s/it]
#                  all         200         595       0.203       0.998       0.992       0.712
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     57/499     12.5G     0.035  0.008849  0.003253    0.0471        41       640: 100% 4/4 [00:04<00:00,  1.20s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:06<00:00,  1.54s/it]
#                  all         200         595       0.221       0.993       0.988       0.716
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     58/499     12.5G   0.03552   0.01019  0.002787   0.04849        70       640: 100% 4/4 [00:04<00:00,  1.15s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:06<00:00,  1.60s/it]
#                  all         200         595        0.14       0.995       0.984       0.661
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     59/499     12.5G   0.03464   0.01049  0.003125   0.04825        72       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:06<00:00,  1.63s/it]
#                  all         200         595       0.065       0.997       0.977       0.553
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     60/499     12.5G   0.03382  0.009587   0.00395   0.04736        56       640: 100% 4/4 [00:04<00:00,  1.14s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:06<00:00,  1.74s/it]
#                  all         200         595      0.0468       0.993       0.951       0.604
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     61/499     12.5G   0.03204  0.009506  0.002588   0.04414        69       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.50s/it]
#                  all         200         595       0.133       0.995       0.972       0.532
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     62/499     12.5G   0.03156  0.009781   0.00234   0.04368        67       640: 100% 4/4 [00:04<00:00,  1.21s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:03<00:00,  1.03it/s]
#                  all         200         595       0.349       0.995       0.983       0.664
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     63/499     12.5G   0.03494  0.008629  0.002913   0.04648        29       640: 100% 4/4 [00:04<00:00,  1.15s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.39s/it]
#                  all         200         595        0.26       0.995       0.984       0.636
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     64/499     12.5G   0.03301   0.01041  0.002842   0.04626        89       640: 100% 4/4 [00:04<00:00,  1.16s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.49s/it]
#                  all         200         595       0.251       0.997       0.969       0.582
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     65/499     12.5G   0.03429  0.009133  0.003149   0.04657        53       640: 100% 4/4 [00:04<00:00,  1.18s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:06<00:00,  1.54s/it]
#                  all         200         595       0.247       0.995       0.972       0.625
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     66/499     12.5G   0.03348  0.009615  0.002788   0.04589        59       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:06<00:00,  1.51s/it]
#                  all         200         595       0.187       0.997       0.968       0.628
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     67/499     12.5G   0.03362  0.008975  0.002956   0.04555        57       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.33s/it]
#                  all         200         595       0.333       0.993       0.986       0.572
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     68/499     12.5G   0.03295  0.009315  0.003013   0.04528        39       640: 100% 4/4 [00:04<00:00,  1.19s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:06<00:00,  1.51s/it]
#                  all         200         595       0.158       0.997       0.981       0.684
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     69/499     12.5G   0.03231  0.008885  0.002802     0.044        49       640: 100% 4/4 [00:04<00:00,  1.15s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.40s/it]
#                  all         200         595       0.282       0.997       0.991       0.692
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     70/499     12.5G   0.02895  0.008521  0.002393   0.03987        39       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:04<00:00,  1.19s/it]
#                  all         200         595       0.375       0.993       0.987       0.637
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     71/499     12.5G   0.03285   0.00979  0.003105   0.04574        73       640: 100% 4/4 [00:04<00:00,  1.23s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.50s/it]
#                  all         200         595       0.254       0.993       0.987       0.697
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     72/499     12.5G   0.03192  0.009514  0.003281   0.04471        75       640: 100% 4/4 [00:04<00:00,  1.18s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:03<00:00,  1.07it/s]
#                  all         200         595       0.347       0.993       0.989       0.666
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     73/499     12.5G   0.03016  0.009789  0.002606   0.04255        64       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:03<00:00,  1.07it/s]
#                  all         200         595         0.4       0.993       0.988       0.722
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     74/499     12.5G   0.02993  0.008342   0.00248   0.04075        52       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.43s/it]
#                  all         200         595        0.31       0.995       0.988       0.708
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     75/499     12.5G   0.02941  0.008054  0.002709   0.04017        46       640: 100% 4/4 [00:04<00:00,  1.15s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:03<00:00,  1.22it/s]
#                  all         200         595        0.41       0.993       0.989        0.69
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     76/499     12.5G   0.02913  0.008321  0.002768   0.04022        50       640: 100% 4/4 [00:04<00:00,  1.15s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:04<00:00,  1.10s/it]
#                  all         200         595       0.469       0.997       0.991       0.698
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     77/499     12.5G   0.02994  0.008437  0.002354   0.04073        59       640: 100% 4/4 [00:04<00:00,  1.16s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.49s/it]
#                  all         200         595       0.235       0.995       0.987       0.694
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     78/499     12.5G   0.03094  0.008182  0.002637   0.04175        52       640: 100% 4/4 [00:04<00:00,  1.18s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:06<00:00,  1.50s/it]
#                  all         200         595       0.246       0.993       0.985       0.685
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     79/499     12.5G    0.0327  0.008599  0.002378   0.04368        52       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:04<00:00,  1.24s/it]
#                  all         200         595       0.357       0.992       0.976       0.562
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     80/499     12.5G   0.03044  0.008381   0.00275   0.04157        41       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.40it/s]
#                  all         200         595       0.536       0.993       0.988       0.709
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     81/499     12.5G   0.02988  0.007809  0.002652   0.04034        42       640: 100% 4/4 [00:04<00:00,  1.15s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:03<00:00,  1.25it/s]
#                  all         200         595        0.43       0.997       0.992       0.735
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     82/499     12.5G   0.03014  0.007958  0.002497   0.04059        37       640: 100% 4/4 [00:04<00:00,  1.16s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.49it/s]
#                  all         200         595        0.63       0.993       0.988       0.708
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     83/499     12.5G   0.02946  0.008656  0.002407   0.04052        54       640: 100% 4/4 [00:04<00:00,  1.22s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.45it/s]
#                  all         200         595       0.503       0.995        0.99       0.742
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     84/499     12.5G   0.02981  0.008792  0.002392     0.041        59       640: 100% 4/4 [00:04<00:00,  1.16s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:03<00:00,  1.29it/s]
#                  all         200         595       0.523       0.995       0.992       0.769
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     85/499     12.5G    0.0305  0.008466  0.002342   0.04131        31       640: 100% 4/4 [00:04<00:00,  1.21s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:03<00:00,  1.21it/s]
#                  all         200         595       0.574       0.995       0.989       0.704
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     86/499     12.5G   0.02998  0.008093  0.002451   0.04052        48       640: 100% 4/4 [00:04<00:00,  1.14s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:04<00:00,  1.24s/it]
#                  all         200         595        0.43       0.997        0.99       0.674
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     87/499     12.5G   0.03051  0.008375  0.002479   0.04136        49       640: 100% 4/4 [00:04<00:00,  1.18s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:04<00:00,  1.19s/it]
#                  all         200         595       0.444       0.997       0.991       0.764
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     88/499     12.5G   0.03134  0.009129  0.002316   0.04279        54       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:06<00:00,  1.52s/it]
#                  all         200         595       0.378       0.997       0.991       0.724
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     89/499     12.5G   0.03064  0.008481  0.002231   0.04135        50       640: 100% 4/4 [00:04<00:00,  1.15s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:03<00:00,  1.17it/s]
#                  all         200         595        0.39       0.998       0.991       0.767
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     90/499     12.5G   0.03251  0.009167  0.003124   0.04481        44       640: 100% 4/4 [00:04<00:00,  1.19s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:03<00:00,  1.16it/s]
#                  all         200         595       0.357       0.997       0.988       0.691
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     91/499     12.5G    0.0293  0.008564  0.002436   0.04029        61       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:03<00:00,  1.15it/s]
#                  all         200         595       0.377       0.997       0.989       0.798
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     92/499     12.5G   0.02974  0.008367  0.002333   0.04044        58       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:04<00:00,  1.15s/it]
#                  all         200         595       0.581       0.995        0.99       0.652
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     93/499     12.5G   0.02955  0.009139  0.002479   0.04117        45       640: 100% 4/4 [00:04<00:00,  1.20s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:03<00:00,  1.17it/s]
#                  all         200         595       0.635       0.992       0.987       0.727
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     94/499     12.5G   0.03113  0.008641  0.002828    0.0426        45       640: 100% 4/4 [00:04<00:00,  1.19s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:04<00:00,  1.10s/it]
#                  all         200         595       0.419       0.993       0.985       0.674
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     95/499     12.5G   0.02874  0.009154  0.002441   0.04033        84       640: 100% 4/4 [00:04<00:00,  1.20s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:03<00:00,  1.01it/s]
#                  all         200         595       0.424        0.99       0.984       0.699
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     96/499     12.5G    0.0286  0.008011  0.002463   0.03907        38       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:03<00:00,  1.23it/s]
#                  all         200         595       0.503       0.976       0.968       0.684
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     97/499     12.5G   0.02919  0.009043  0.002449   0.04068        58       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:04<00:00,  1.11s/it]
#                  all         200         595       0.426       0.993       0.987       0.689
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     98/499     12.5G    0.0288  0.007709  0.002219   0.03873        30       640: 100% 4/4 [00:04<00:00,  1.14s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.44s/it]
#                  all         200         595        0.36       0.995       0.989       0.739
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     99/499     12.5G   0.03047   0.00919   0.00258   0.04224        74       640: 100% 4/4 [00:04<00:00,  1.16s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.50s/it]
#                  all         200         595       0.231        0.99        0.98       0.634
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    100/499     12.5G   0.03006  0.009243  0.002562   0.04187        74       640: 100% 4/4 [00:04<00:00,  1.15s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:06<00:00,  1.53s/it]
#                  all         200         595       0.217       0.998       0.991       0.749
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    101/499     12.5G   0.03164   0.00791  0.002527   0.04208        42       640: 100% 4/4 [00:04<00:00,  1.14s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:05<00:00,  1.29s/it]
#                  all         200         595       0.245           1       0.992       0.708
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    102/499     12.5G   0.03018  0.007747  0.002398   0.04032        47       640: 100% 4/4 [00:04<00:00,  1.13s/it]
# ...
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.69it/s]
#                  all         200         595       0.686           1       0.995        0.88
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    463/499     12.5G   0.01759  0.005462  0.001682   0.02473        56       640: 100% 4/4 [00:04<00:00,  1.18s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.70it/s]
#                  all         200         595       0.692           1       0.995        0.88
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    464/499     12.5G   0.01706  0.005042  0.001659   0.02376        33       640: 100% 4/4 [00:04<00:00,  1.23s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.71it/s]
#                  all         200         595       0.699           1       0.995       0.889
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    465/499     12.5G   0.01786  0.005552  0.002156   0.02556        58       640: 100% 4/4 [00:04<00:00,  1.19s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.69it/s]
#                  all         200         595       0.709           1       0.995       0.866
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    466/499     12.5G   0.01707  0.004838  0.001428   0.02333        25       640: 100% 4/4 [00:04<00:00,  1.16s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.68it/s]
#                  all         200         595       0.744           1       0.995       0.889
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    467/499     12.5G   0.01823  0.005627  0.001796   0.02565        43       640: 100% 4/4 [00:04<00:00,  1.19s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.72it/s]
#                  all         200         595       0.733           1       0.995       0.876
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    468/499     12.5G   0.01832  0.006018  0.001662     0.026        85       640: 100% 4/4 [00:04<00:00,  1.19s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.73it/s]
#                  all         200         595       0.718           1       0.995       0.889
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    469/499     12.5G   0.01812  0.005348  0.001762   0.02523        33       640: 100% 4/4 [00:04<00:00,  1.18s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.69it/s]
#                  all         200         595       0.668           1       0.995       0.874
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    470/499     12.5G   0.01804   0.00611  0.001851     0.026        62       640: 100% 4/4 [00:04<00:00,  1.15s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.73it/s]
#                  all         200         595       0.689           1       0.995       0.881
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    471/499     12.5G   0.01795  0.006238  0.001546   0.02574        69       640: 100% 4/4 [00:04<00:00,  1.18s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.71it/s]
#                  all         200         595       0.709           1       0.995       0.874
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    472/499     12.5G   0.01809   0.00545  0.001832   0.02537        38       640: 100% 4/4 [00:04<00:00,  1.16s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.71it/s]
#                  all         200         595       0.725           1       0.995       0.892
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    473/499     12.5G   0.01785  0.005629  0.001517   0.02499        40       640: 100% 4/4 [00:04<00:00,  1.20s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.68it/s]
#                  all         200         595        0.73           1       0.995       0.891
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    474/499     12.5G   0.01802  0.005042   0.00171   0.02477        37       640: 100% 4/4 [00:04<00:00,  1.19s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.64it/s]
#                  all         200         595       0.732           1       0.995       0.899
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    475/499     12.5G   0.01785  0.005254  0.001769   0.02487        30       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.68it/s]
#                  all         200         595       0.732           1       0.995        0.89
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    476/499     12.5G   0.01733  0.005348  0.001629   0.02431        39       640: 100% 4/4 [00:04<00:00,  1.16s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.62it/s]
#                  all         200         595       0.715           1       0.995         0.9
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    477/499     12.5G   0.01702  0.006047  0.001662   0.02473        68       640: 100% 4/4 [00:04<00:00,  1.16s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.67it/s]
#                  all         200         595       0.707           1       0.995       0.894
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    478/499     12.5G    0.0194  0.005451  0.002075   0.02693        39       640: 100% 4/4 [00:04<00:00,  1.18s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.53it/s]
#                  all         200         595       0.687           1       0.995       0.899
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    479/499     12.5G   0.01684  0.005463  0.001559   0.02386        48       640: 100% 4/4 [00:04<00:00,  1.18s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.55it/s]
#                  all         200         595       0.646           1       0.995       0.898
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    480/499     12.5G   0.01895  0.005898  0.002005   0.02685        56       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.54it/s]
#                  all         200         595       0.649           1       0.995       0.907
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    481/499     12.5G   0.01798  0.005282  0.001748   0.02501        26       640: 100% 4/4 [00:04<00:00,  1.21s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.64it/s]
#                  all         200         595       0.707           1       0.995       0.873
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    482/499     12.5G   0.01873  0.006318  0.001845    0.0269        62       640: 100% 4/4 [00:04<00:00,  1.20s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.66it/s]
#                  all         200         595       0.751           1       0.995       0.883
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    483/499     12.5G   0.01734  0.005705  0.001698   0.02474        55       640: 100% 4/4 [00:04<00:00,  1.20s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.70it/s]
#                  all         200         595       0.702           1       0.995       0.883
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    484/499     12.5G    0.0182  0.005711  0.001625   0.02554        58       640: 100% 4/4 [00:04<00:00,  1.20s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.70it/s]
#                  all         200         595       0.712           1       0.995       0.884
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    485/499     12.5G   0.01767  0.005845  0.001617   0.02513        38       640: 100% 4/4 [00:04<00:00,  1.19s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.68it/s]
#                  all         200         595       0.746           1       0.995       0.885
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    486/499     12.5G   0.01719  0.005271  0.001669   0.02413        37       640: 100% 4/4 [00:04<00:00,  1.20s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.72it/s]
#                  all         200         595       0.731           1       0.995        0.88
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    487/499     12.5G   0.01759  0.005662  0.001759   0.02501        54       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.71it/s]
#                  all         200         595       0.743           1       0.995       0.893
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    488/499     12.5G   0.01853  0.005495  0.001717   0.02574        35       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.72it/s]
#                  all         200         595       0.741           1       0.995       0.891
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    489/499     12.5G    0.0182  0.006031  0.001831   0.02606        58       640: 100% 4/4 [00:04<00:00,  1.16s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.70it/s]
#                  all         200         595       0.745           1       0.995       0.896
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    490/499     12.5G   0.01801   0.00599  0.001704    0.0257        47       640: 100% 4/4 [00:04<00:00,  1.20s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.62it/s]
#                  all         200         595       0.736           1       0.995       0.892
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    491/499     12.5G   0.01849  0.005683   0.00167   0.02584        54       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.47it/s]
#                  all         200         595       0.713           1       0.995       0.893
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    492/499     12.5G   0.01935  0.005856  0.001804   0.02701        58       640: 100% 4/4 [00:04<00:00,  1.19s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.53it/s]
#                  all         200         595       0.713           1       0.995       0.896
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    493/499     12.5G   0.01891  0.006028  0.001684   0.02662        42       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.61it/s]
#                  all         200         595       0.701           1       0.995        0.91
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    494/499     12.5G   0.01753  0.005799  0.001657   0.02498        57       640: 100% 4/4 [00:04<00:00,  1.17s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.34it/s]
#                  all         200         595       0.603           1       0.995       0.895
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    495/499     12.5G   0.01872   0.00595  0.001682   0.02635        59       640: 100% 4/4 [00:04<00:00,  1.19s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.34it/s]
#                  all         200         595       0.607           1       0.995        0.89
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    496/499     12.5G    0.0176  0.005624  0.001809   0.02503        63       640: 100% 4/4 [00:04<00:00,  1.21s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.66it/s]
#                  all         200         595       0.736           1       0.995       0.885
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    497/499     12.5G   0.01763  0.005631   0.00193   0.02519        73       640: 100% 4/4 [00:04<00:00,  1.21s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.68it/s]
#                  all         200         595       0.762           1       0.995       0.887
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    498/499     12.5G   0.01939  0.006086    0.0023   0.02778        64       640: 100% 4/4 [00:04<00:00,  1.16s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.69it/s]
#                  all         200         595       0.731           1       0.995       0.874
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    499/499     12.5G   0.01776  0.005555  0.001633   0.02494        46       640: 100% 4/4 [00:04<00:00,  1.18s/it]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 4/4 [00:02<00:00,  1.65it/s]
#                  all         200         595       0.724           1       0.995         0.9
# Optimizer stripped from /mydrive/yolov5/exp8_rear_truck_photos_enlarged_bbox/weights/last_rear_truck_photos_enlarged_bbox.pt, 14.8MB
# 500 epochs completed in 1.176 hours.

# %% [markdown]
# Removing 4th channel of pngs as needed for training
#
# (model doesn't recogize their sRGB profile)

# %%
#Removing the 4th channel for the pngs as needed
#from train_test_rear_truck_photos2.zip

from glob import glob
import os
from PIL import Image
import cv2

training_pngs = sorted(glob('/content/rear_truck_photos/training_photos/*.png'))

for png in training_pngs:
    filepath, filename = os.path.split(png)
    filename_no_ext = (filename.split('.')[0])#.replace(' ', '_') # used to remove spaces
    img = Image.open(png)
    rgb_img = img.convert('RGB')
    rgb_img.save(f'{filepath}/{filename_no_ext}.jpg')


# matching txt file names to png file names - doesn't seem to work 100%
# training_txts = sorted(glob('/content/rear_truck_photos/training_photos/*.txt'))

# for txt in training_txts:
#     filepath, filename = os.path.split(txt)
#     filename_no_ext = (filename.split('.')[0]).replace(' ', '_')
#     os.rename(txt, f'{filepath}/{filename_no_ext}.txt')

# for png in training_pngs:
#     filepath, filename = os.path.split(png)
#     filename_no_ext = (filename.split('.')[0]).replace(' ', '_')
#     img = cv2.imread(png)
#     rgb_img = cv2.cvtColor(img, cv2.COLOR_BGRA2RGB)
#     cv2.imwrite(f'{filepath}/{filename_no_ext}.png', rgb_img)
#above option did not fix artifact issues

# %%
# !mkdir ../3000e_training_set2
# !mv ../rear_truck_photos/training_photos/*.jpg ../3000e_training_set2
# !mv ../rear_truck_photos/training_photos/*.txt ../3000e_training_set2

# %%
# !ls
# Out:
# data				    requirements_2.txt
# detect_photo_crops.py		    requirements.txt
# detect_photo_dims_to_csv.py	    tailgate_utils.py
# detect_photo.py			    test.py
# detect.py			    top100_csv_processing.ipynb
# Dockerfile			    Top100List_BodyStyle_AllStyles.csv
# hubconf.py			    train.py
# inference			    tutorial.ipynb
# LICENSE				    utils
# models				    weights
# randomize_truck_photo_train_set.py  YOLOv5_Tailgate_Detect.ipynb
# README.md

# %% [markdown]
# # Visualize
#
# View `runs/exp0/train*.jpg` images to see training images, labels and augmentation effects. A **Mosaic Dataloader** is used for training (shown below), a new concept developed by Ultralytics and first featured in [YOLOv4](https://arxiv.org/abs/2004.10934).

# %%
Image(filename='/mydrive/yolov5/exp1_tailgate_handle/train_batch1.jpg', width=900)  # view augmented training mosaics

# %% [markdown]
# View `test_batch0_gt.jpg` to see test batch 0 *ground truth* labels.

# %%
Image(filename='/mydrive/yolov5/exp1_tailgate_handle/test_batch0_gt.jpg', width=900)  # view test image labels

# %% [markdown]
# View `test_batch0_pred.jpg` to see test batch 0 *predictions*.

# %%
# for some reaons the bboxes aren't recorded here, but they are when using detect.py
Image(filename='/mydrive/yolov5/exp1_tailgate_handle/test_batch0_pred.jpg', width=900)  # view test image predictions

# %%
Image(filename='/mydrive/yolov5/exp14_rear_truck_photos_enlarged_bbox/results.png', width=900)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-7585eabdee88> in <module>()
# ----> 1 Image(filename='/mydrive/yolov5/exp14_rear_truck_photos_enlarged_bbox/results.png', width=900)
#
# TypeError: 'module' object is not callable

# %% [markdown]
# Training losses and performance metrics are saved to Tensorboard and also to a `runs/exp0/results.txt` logfile. `results.txt` is plotted as `results.png` after training completes. Partially completed `results.txt` files can be plotted with `from utils.general import plot_results; plot_results()`.

# %% [markdown]
# # Detection and Testing

# %%
# # import and unzip test set
# !cp /mydrive/yolov5/tailgate_.zip ../

# %cd ../
# !mkdir ./test_set/
# !mkdir ./test_set/model_output/
# # unzipping file into the test_set folder
# %cd ./test_set
# !unzip ../tailgate_test_set.zip
# # getting back to yolo folder 
# %cd ../yolov5

# %%
# %ls
# Out:
# data/                               requirements_2.txt*
# detect_photo_crops.py               requirements.txt*
# detect_photo_dims_to_csv.py         scratchpad.py
# detect_photo.py                     tailgate_utils.py
# detect.py                           test.py
# Dockerfile                          top100_csv_processing.ipynb
# hubconf.py                          Top100List_BodyStyle_AllStyles.csv
# inference/                          train.py
# LICENSE                             tutorial.ipynb
# models/                             utils/
# randomize_truck_photo_train_set.py  weights/
# README.md*                          YOLOv5_Tailgate_Detect.ipynb

# %%
# Single Detection

# tailgate not found process
# !python detect_photo_crops.py --weights /mydrive/Biggie/yolov5/exp8_rear_truck_photos_enlarged_bbox/weights/last_rear_truck_photos_enlarged_bbox.pt --source /content/rear_truck_photos/10288_2015FordF-150_2400.png

# proof main process works 
# !python detect_photo_crops.py --weights /mydrive/Biggie/yolov5/exp8_rear_truck_photos_enlarged_bbox/weights/last_rear_truck_photos_enlarged_bbox.pt --source /content/rear_truck_photos/10007_2015GMCSierra\ 1500_2400.png

# proof border works  
# !python detect_photo_crops.py --weights /mydrive/Biggie/yolov5/exp8_rear_truck_photos_enlarged_bbox/weights/last_rear_truck_photos_enlarged_bbox.pt --source /content/rear_truck_photos/1090_2002DodgeDakota_1280.jpg

# tailgate not found on Red Nissan Frontier
# !python detect_photo_crops.py --weights /mydrive/Biggie/yolov5/exp8_rear_truck_photos_enlarged_bbox/weights/last_rear_truck_photos_enlarged_bbox.pt --source /content/rear_truck_photos/10273_2015NissanFrontier_2400.png
 
# darken process and corner process works
# !python detect_photo_crops.py --weights /mydrive/Biggie/yolov5/exp8_rear_truck_photos_enlarged_bbox/weights/last_rear_truck_photos_enlarged_bbox.pt --source /content/rear_truck_photos/1872_2004FordRanger_1280.jpg

# another white truck works
# !python detect_photo_crops.py --weights /mydrive/Biggie/yolov5/exp8_rear_truck_photos_enlarged_bbox/weights/last_rear_truck_photos_enlarged_bbox.pt --source /content/rear_truck_photos/6698_2010GMCCanyon_2400.png
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', img_size=640, iou_thres=0.5, output='inference/output', save_txt=False, source='/content/rear_truck_photos/10007_2015GMCSierra 1500_2400.png', update=False, view_img=False, weights=['/mydrive/Biggie/yolov5/exp8_rear_truck_photos_enlarged_bbox/weights/last_rear_truck_photos_enlarged_bbox.pt'])
# Using CPU
#
# Fusing layers...
# Model Summary: 140 layers, 7.25191e+06 parameters, 6.61683e+06 gradients
# image 1/1 /content/rear_truck_photos/10007_2015GMCSierra 1500_2400.png: 512x640 1 tailgates, 1 handles, 1 plates, Done. (0.409s)
# Results saved to inference/output
# Done. (1.082s)

# %% [markdown]
# Predict on Entire Folder

# %%
# %mkdir /content/test_group_photos/

# %%
from glob import glob

training_pngs = sorted(glob('/content/rear_truck_photos/*.png'))[:10]

for png in training_pngs:
    deal_with_space = png.replace(' ', '\ ')
    # !mv {deal_with_space} /content/test_group_photos/

# %%
# %cd yolov5/
# Out:
# /content/yolov5

# %%
# !python detect_photo_crops.py --weights /mydrive/Biggie/yolov5/exp8_rear_truck_photos_enlarged_bbox/weights/last_rear_truck_photos_enlarged_bbox.pt --source /content/test_group_photos/
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', img_size=640, iou_thres=0.5, output='inference/output', save_txt=False, source='/content/test_group_photos/', update=False, view_img=False, weights=['/mydrive/Biggie/yolov5/exp8_rear_truck_photos_enlarged_bbox/weights/last_rear_truck_photos_enlarged_bbox.pt'])
# Using CPU
#
# Fusing layers...
# Model Summary: 140 layers, 7.25191e+06 parameters, 6.61683e+06 gradients
# image 1/13 /content/test_group_photos/10007_2015GMCSierra_1500_2400.png: 512x640 1 tailgates, 1 handles, 1 plates, Done. (0.414s)
# image 2/13 /content/test_group_photos/10013_2015RAM2500_2400.png: 512x640 1 tailgates, 1 handles, 1 plates, Done. (0.384s)
# image 3/13 /content/test_group_photos/10058_2015ChevroletSilverado 1500_2400.png: 512x640 1 tailgates, 1 handles, 1 plates, Done. (0.385s)
# image 4/13 /content/test_group_photos/10063_2015RAM1500_2400.png: 512x640 1 tailgates, 1 handles, 1 plates, Done. (0.377s)
# image 5/13 /content/test_group_photos/10066_2015RAM1500_2400.png: 512x640 1 tailgates, 1 handles, 1 plates, Done. (0.382s)
# image 6/13 /content/test_group_photos/10082_2015ChevroletSilverado 1500_2400.png: 512x640 1 tailgates, 1 handles, 1 plates, Done. (0.377s)
# image 7/13 /content/test_group_photos/10083_2015ChevroletSilverado 1500_2400.png: 512x640 1 tailgates, 1 handles, 1 plates, Done. (0.383s)
# image 8/13 /content/test_group_photos/10084_2015ChevroletSilverado 1500_2400.png: 512x640 1 tailgates, 1 handles, 1 plates, Done. (0.405s)
# image 9/13 /content/test_group_photos/10086_2015ChevroletSilverado 1500_2400.png: 512x640 1 tailgates, 1 handles, 1 plates, Done. (0.423s)
# image 10/13 /content/test_group_photos/10088_2015ChevroletSilverado 1500_2400.png: 512x640 1 tailgates, 1 handles, 1 plates, Done. (0.534s)
# image 11/13 /content/test_group_photos/10089_2015RAM1500_2400.png: 512x640 1 tailgates, 1 handles, 1 plates, Done. (0.381s)
# image 12/13 /content/test_group_photos/10090_2015RAM1500_2400.png: 512x640 1 tailgates, 1 handles, 1 plates, Done. (0.404s)
# image 13/13 /content/test_group_photos/10091_2015RAM1500_2400.png: 512x640 1 tailgates, 1 handles, 1 plates, Done. (0.377s)
# Results saved to inference/output
# Done. (68.956s)
